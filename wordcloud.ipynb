# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = input("")

cloud = WordCloud(background_color = "white").generate(text)

plt.imshow(cloud)
plt.axis('off')
plt.show()
# Out:
# idis jnfihdi f ishv  hsdiuf  jdihf
